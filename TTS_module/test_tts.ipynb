# %%
from transformers import VitsModel, AutoTokenizer
from IPython.display import Audio
import torch

model = VitsModel.from_pretrained("facebook/mms-tts-rus")
tokenizer = AutoTokenizer.from_pretrained("facebook/mms-tts-rus")

text = "Привет! Как дела? Куда дела свою кошку?"
inputs = tokenizer(text, return_tensors="pt")

with torch.no_grad():
    output = model(**inputs).waveform

Audio(output, rate=model.config.sampling_rate)

# %%
from transformers import VitsModel, AutoTokenizer
from IPython.display import Audio
import torch

model_id = "Ftfyhh/xttsv2_banana"
model = VitsModel.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)

text = "Привет! Как дела? Куда дела свою кошку?"
inputs = tokenizer(text, return_tensors="pt")

with torch.no_grad():
    output = model(**inputs).waveform

Audio(output, rate=model.config.sampling_rate)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.7/envs/testing/lib/python3.11/site-packages/huggingface_hub/utils/_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File ~/.pyenv/versions/3.11.7/envs/testing/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/Ftfyhh/xttsv2_banana/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# ...

# %%
import torch
from TTS.api import TTS

# Get device
device = "cuda" if torch.cuda.is_available() else "cpu"

# List available 🐸TTS models
tts = TTS("Ftfyhh/xttsv2_banana/model_banana").to(device)
wav = tts.tts(
    "Кто лучшая киса? Дашуша кшуша пуша",
    speaker_wav="../audio_samples/audio5.ogg",
    language="ru",
)

Audio(wav, rate=24000)
# Out:
#  > Using model: xtts
#  > Text splitted to sentences.
# ['Кто лучшая киса?', 'Дашуша кшуша пуша']
#  > Processing time: 1.0155234336853027
#  > Real-time factor: 0.21697957086008648
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
